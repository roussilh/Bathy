# %%
import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy.ma as ma
import numpy as np
import cmocean
import matplotlib
from numpy import zeros,array
# %matplotlib inline

# %%
L=array([0.0025169337,0.0035909452,0.0033775966,0.0030532414,0.002982492,0.0030841837,0.0029339227,0.003345674,0.0029345434,0.0031844082,0.003399711,0.003458972])
print(L)
# Out:
# [0.00251693 0.00359095 0.0033776  0.00305324 0.00298249 0.00308418
#  0.00293392 0.00334567 0.00293454 0.00318441 0.00339971 0.00345897]

# %%
L.shape
# Out:
# (12,)

# %%
etype = np.std(L)
print(etype)
# Out:
# 0.0002856038071850917

# %%
plt.figure(figsize=(12,12))
plt.plot(L,c="red")
plt.title('Energie cinétique moyenne de juillet 2009 à juin 2010')
plt.xlabel('mois')
plt.ylabel('Ec moyenne')
errorL = [etype]
plt.errorbar(range(len(L)), L, yerr = errorL,
    fmt = 'none', capsize = 5, ecolor = 'red', elinewidth = 1, capthick = 2)
axes = plt.gca()
axes.xaxis.set_ticks(range(12)) 
axes.xaxis.set_ticklabels(['juillet', 'aout', 'septembre', 'octobre', 'novembre', 'decembre', 'janvier', 'fevrier', 'mars', 'avril', 'mai', 'juin'])
plt.savefig('Ec_moy_zone_gyre_subpolaire_zone2_jui09_juin10.png', bbbox_inches='tight')
# Out:
# /tmp/ipykernel_76109/3887555142.py:12: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbbox_inches" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('Ec_moy_zone_gyre_subpolaire_zone2_jui09_juin10.png', bbbox_inches='tight')
