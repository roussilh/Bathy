# %%
import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy.ma as ma
import numpy as np
import cmocean
import matplotlib
# %matplotlib inline

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m07.1m_Vbottomdegrad.nc'
AZE=xr.open_mfdataset(multi_dataDIR,concat_dim='t', combine='nested')
AZE
# Out:
# <xarray.Dataset>
# Dimensions:            (t: 1, y: 1182, x: 1480)
# Dimensions without coordinates: t, y, x
# Data variables:
#     degraded_vomecrty  (t, y, x) float32 dask.array<chunksize=(1, 1182, 1480), meta=np.ndarray>

# %%
u = AZE.degraded_vomecrty
print(u.values)
# Out:
# [[[       nan        nan        nan ...        nan        nan        nan]
#   [       nan        nan        nan ...        nan        nan        nan]
#   [       nan        nan        nan ...        nan        nan        nan]
#   ...
#   [       nan        nan        nan ... 0.01513039 0.00601585 0.00747747]
#   [       nan        nan        nan ... 0.02071779 0.01747866 0.0137916 ]
#   [       nan        nan        nan ... 0.01550234 0.01156458 0.009332  ]]]

# %%
dirf='/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m07d03.1h_Vbottomdegrad.nc'
ds=xr.open_dataset(dirf,decode_times=False)
ds
# Out:
# <xarray.Dataset>
# Dimensions:            (time_counter: 24, y: 1182, x: 1480, depthv: 1)
# Coordinates:
#   * depthv             (depthv) float32 0.4805
#   * time_counter       (time_counter) float64 3.456e+09 3.456e+09 ... 3.456e+09
# Dimensions without coordinates: y, x
# Data variables:
#     degraded_vomecrty  (time_counter, y, x) float32 ...
#     nav_lat            (y, x) float32 ...
#     nav_lon            (y, x) float32 ...
# Attributes:
#     start_date:        -1
#     output_frequency:  N/A
#     CONFIG:            N/A
#     CASE:              N/A
#     history:           Mon May  9 15:14:11 2022: ncks -O -x -v flsdc test_eNA...
#     NCO:               netCDF Operators version 4.7.4-alpha04 (http://nco.sf....

# %%
nav_lat =ds.nav_lat
nav_lon=ds.nav_lon

# %%
lonmin=-70
lonmax=-50
latmin=30
latmax=40
domain = (lonmin<nav_lon) * (nav_lon<lonmax) * (latmin<nav_lat) * (nav_lat<latmax)
where = np.where(domain)

# %%
imin=where[0].min()
imax=where[0].max()
jmin=where[1].min()
jmax=where[1].max()

# %%
print(imin,imax,jmin,jmax)
# Out:
# 377 569 418 719

# %%
E=u*u
print(E.values)
# Out:
# [[[          nan           nan           nan ...           nan
#              nan           nan]
#   [          nan           nan           nan ...           nan
#              nan           nan]
#   [          nan           nan           nan ...           nan
#              nan           nan]
#   ...
#   [          nan           nan           nan ... 2.2892858e-04
#    3.6190409e-05 5.5912587e-05]
#   [          nan           nan           nan ... 4.2922684e-04
#    3.0550361e-04 1.9020826e-04]
#   [          nan           nan           nan ... 2.4032244e-04
#    1.3373952e-04 8.7086228e-05]]]

# %%
Ezoom=E[imin:imax,jmin:jmax]
Ezoom.shape
# Out:
# (0, 301, 1480)

# %%
m=Ezoom.mean(dim={'x','y'})
m
# Out:
# <xarray.DataArray 'degraded_vomecrty' (t: 0)>
# dask.array<mean_agg-aggregate, shape=(0,), dtype=float32, chunksize=(0,), chunktype=numpy.ndarray>
# Dimensions without coordinates: t

# %%
print(m.values)
# Out:
# []

# %%
multi_dataDIR2 = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m07.1m_Ubottomdegrad.nc'
AZR=xr.open_mfdataset(multi_dataDIR2,concat_dim='t', combine='nested')
AZR
# Out:
# <xarray.Dataset>
# Dimensions:            (t: 1, y: 1181, x: 1480)
# Dimensions without coordinates: t, y, x
# Data variables:
#     degraded_vozocrtx  (t, y, x) float32 dask.array<chunksize=(1, 1181, 1480), meta=np.ndarray>

# %%
umean2 = AZR.degraded_vozocrtx
umean2
# Out:
# <xarray.DataArray 'degraded_vozocrtx' (t: 1, y: 1181, x: 1480)>
# dask.array<broadcast_to, shape=(1, 1181, 1480), dtype=float32, chunksize=(1, 1181, 1480), chunktype=numpy.ndarray>
# Dimensions without coordinates: t, y, x

# %%
dirf1='/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m07d01.1h_Ubottomdegrad.nc'
ls=xr.open_dataset(dirf,decode_times=False)
ls
# Out:
# <xarray.Dataset>
# Dimensions:            (time_counter: 24, y: 1182, x: 1480, depthv: 1)
# Coordinates:
#   * depthv             (depthv) float32 0.4805
#   * time_counter       (time_counter) float64 3.456e+09 3.456e+09 ... 3.456e+09
# Dimensions without coordinates: y, x
# Data variables:
#     degraded_vomecrty  (time_counter, y, x) float32 ...
#     nav_lat            (y, x) float32 ...
#     nav_lon            (y, x) float32 ...
# Attributes:
#     start_date:        -1
#     output_frequency:  N/A
#     CONFIG:            N/A
#     CASE:              N/A
#     history:           Mon May  9 15:14:11 2022: ncks -O -x -v flsdc test_eNA...
#     NCO:               netCDF Operators version 4.7.4-alpha04 (http://nco.sf....

# %%
nav_lat =ds.nav_lat
nav_lon=ds.nav_lon

# %%
lonmin=-70
lonmax=-50
latmin=30
latmax=40
domain = (lonmin<nav_lon) * (nav_lon<lonmax) * (latmin<nav_lat) * (nav_lat<latmax)
where = np.where(domain)

# %%
imin=where[0].min()
imax=where[0].max()
jmin=where[1].min()
jmax=where[1].max()

# %%
print(imin,imax,jmin,jmax)
# Out:
# 377 569 418 719

# %%
E2=umean2*umean2

# %%
Ezoom2=E2[imin:imax,jmin:jmax]
Ezoom2.shape
# Out:
# (0, 301, 1480)

# %%
m2=Ezoom2.mean(dim={'x','y'})
m2
# Out:
# <xarray.DataArray 'degraded_vozocrtx' (t: 0)>
# dask.array<mean_agg-aggregate, shape=(0,), dtype=float32, chunksize=(0,), chunktype=numpy.ndarray>
# Dimensions without coordinates: t

# %%
print(m2.values)
# Out:
# []

# %%
w= (m2+m).mean
print(w)
# Out:
# <bound method ImplementsArrayReduce._reduce_method.<locals>.wrapped_func of <xarray.DataArray (t: 0)>
# dask.array<add, shape=(0,), dtype=float32, chunksize=(0,), chunktype=numpy.ndarray>
# Dimensions without coordinates: t>

# %%
#Ec mois de juillet
Ec=1/2*(w)
print(Ec.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [124], in <cell line: 2>()
#       1 #Ec mois de juillet
# ----> 2 Ec=1/2*(w)
#       3 print(Ec.values)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'method'

# %%
#moy mois août
multi_dataDIRA = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m08.1m_Vbottomdegrad.nc'
AZA=xr.open_mfdataset(multi_dataDIRA,concat_dim='t', combine='nested')
umeanA = AZA.degraded_vomecrty.mean(dim='t')

# %%
EA=umeanA*umeanA
EzoomA=EA[imin:imax,jmin:jmax]
mA=EzoomA.mean(dim={'x','y'})
print(mA.values)

# %%
multi_dataDIR2A = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m08.1m_Ubottomdegrad.nc'
AZRA=xr.open_mfdataset(multi_dataDIR2A,concat_dim='t', combine='nested')
umean2A = AZRA.degraded_vozocrtx.mean(dim='t')

# %%
E2A=umean2A*umean2A
Ezoom2A=E2A[imin:imax,jmin:jmax]
m2A=Ezoom2A.mean(dim={'x','y'})
print(m2A.values)

# %%
#Ec mois de août
EcA=1/2*(m2A+mA)
print(EcA.values)

# %%
#moy mois de septembre
multi_dataDIRS = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m09.1m_Vbottomdegrad.nc'
AZS=xr.open_mfdataset(multi_dataDIRS,concat_dim='t', combine='nested')
umeanS = AZS.degraded_vomecrty.mean(dim='t')

# %%
ES=umeanS*umeanS
EzoomS=ES[imin:imax,jmin:jmax]
mS=EzoomS.mean(dim={'x','y'})
print(mS.values)

# %%
multi_dataDIR2S = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m09.1m_Ubottomdegrad.nc'
AZRS=xr.open_mfdataset(multi_dataDIR2S,concat_dim='t', combine='nested')
umean2S = AZRS.degraded_vozocrtx.mean(dim='t')

# %%
E2S=umean2S*umean2S
Ezoom2S=E2S[imin:imax,jmin:jmax]
m2S=Ezoom2S.mean(dim={'x','y'})
print(m2S.values)

# %%
#Ec mois de septembre
EcS=1/2*(m2S+mS)
print(EcS.values)

# %%
#moy mois de octobre
multi_dataDIRO = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m10.1m_Vbottomdegrad.nc'
AZO=xr.open_mfdataset(multi_dataDIRO,concat_dim='t', combine='nested')
umeanO = AZO.degraded_vomecrty.mean(dim='t')

# %%
EO=umeanO*umeanO
EzoomO=EO[imin:imax,jmin:jmax]
mO=EzoomO.mean(dim={'x','y'})
print(mO.values)

# %%
multi_dataDIR2O = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m10.1m_Ubottomdegrad.nc'
AZRO=xr.open_mfdataset(multi_dataDIR2O,concat_dim='t', combine='nested')
umean2O = AZRO.degraded_vozocrtx.mean(dim='t')

# %%
E2O=umean2O*umean2O
Ezoom2O=E2O[imin:imax,jmin:jmax]
m2O=Ezoom2O.mean(dim={'x','y'})
print(m2O.values)

# %%
#Ec mois de octobre
EcO=1/2*(m2O+mO)
print(EcO.values)

# %%
#moy mois de novembre
multi_dataDIRN = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m11.1m_Vbottomdegrad.nc'
AZN=xr.open_mfdataset(multi_dataDIRN,concat_dim='t', combine='nested')
umeanN = AZN.degraded_vomecrty.mean(dim='t')

# %%
EN=umeanN*umeanN
EzoomN=EN[imin:imax,jmin:jmax]
mN=EzoomN.mean(dim={'x','y'})
print(mN.values)

# %%
multi_dataDIR2N = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m11.1m_Ubottomdegrad.nc'
AZRN=xr.open_mfdataset(multi_dataDIR2N,concat_dim='t', combine='nested')
umean2N = AZRN.degraded_vozocrtx.mean(dim='t')

# %%
E2N=umean2N*umean2N
Ezoom2N=E2N[imin:imax,jmin:jmax]
m2N=Ezoom2N.mean(dim={'x','y'})
print(m2N.values)

# %%
#Ec mois de novembre
EcN=1/2*(m2N+mN)
print(EcN.values)

# %%
#moy mois de décembre
multi_dataDIRD = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m12.1m_Vbottomdegrad.nc'
AZD=xr.open_mfdataset(multi_dataDIRD,concat_dim='t', combine='nested')
umeanD = AZD.degraded_vomecrty.mean(dim='t')

# %%
ED=umeanD*umeanD
EzoomD=ED[imin:imax,jmin:jmax]
mD=EzoomD.mean(dim={'x','y'})
print(mD.values)

# %%
multi_dataDIR2D = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2009m12.1m_Ubottomdegrad.nc'
AZRD=xr.open_mfdataset(multi_dataDIR2D,concat_dim='t', combine='nested')
umean2D = AZRD.degraded_vozocrtx.mean(dim='t')

# %%
E2D=umean2D*umean2D
Ezoom2D=E2D[imin:imax,jmin:jmax]
m2D=Ezoom2D.mean(dim={'x','y'})
print(m2D.values)

# %%
#Ec mois de décembre
EcD=1/2*(m2D+mD)
print(EcD.values)

# %%
#moy mois de janvier
multi_dataDIRJ = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m01.1m_Vbottomdegrad.nc'
AZJ=xr.open_mfdataset(multi_dataDIRJ,concat_dim='t', combine='nested')
umeanJ = AZJ.degraded_vomecrty.mean(dim='t')

# %%
EJ=umeanJ*umeanJ
EzoomJ=EJ[imin:imax,jmin:jmax]
mJ=EzoomJ.mean(dim={'x','y'})
print(mJ.values)

# %%
multi_dataDIR2J = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m01.1m_Ubottomdegrad.nc'
AZRJ=xr.open_mfdataset(multi_dataDIR2J,concat_dim='t', combine='nested')
umean2J = AZRJ.degraded_vozocrtx.mean(dim='t')

# %%
E2J=umean2J*umean2J
Ezoom2J=E2J[imin:imax,jmin:jmax]
m2J=Ezoom2J.mean(dim={'x','y'})
print(m2J.values)

# %%
#Ec mois de janvier
EcJ=1/2*(m2J+mJ)
print(EcJ.values)

# %%
#moy mois de fevrier
multi_dataDIRF = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m02.1m_Vbottomdegrad.nc'
AZF=xr.open_mfdataset(multi_dataDIRF,concat_dim='t', combine='nested')
umeanF = AZF.degraded_vomecrty.mean(dim='t')

# %%
EF=umeanF*umeanF
EzoomF=EF[imin:imax,jmin:jmax]
mF=EzoomF.mean(dim={'x','y'})
print(mF.values)

# %%
multi_dataDIR2F = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m02.1m_Ubottomdegrad.nc'
AZRF=xr.open_mfdataset(multi_dataDIR2F,concat_dim='t', combine='nested')
umean2F = AZRF.degraded_vozocrtx.mean(dim='t')

# %%
E2F=umean2F*umean2F
Ezoom2F=E2F[imin:imax,jmin:jmax]
m2F=Ezoom2F.mean(dim={'x','y'})
print(m2F.values)

# %%
#Ec mois de fevrier
EcF=1/2*(m2F+mF)
print(EcF.values)

# %%
#moy mois de MARS
multi_dataDIRM = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m03.1m_Vbottomdegrad.nc'
AZM=xr.open_mfdataset(multi_dataDIRM,concat_dim='t', combine='nested')
umeanM = AZM.degraded_vomecrty.mean(dim='t')

# %%
EM=umeanM*umeanM
EzoomM=EM[imin:imax,jmin:jmax]
mM=EzoomM.mean(dim={'x','y'})
print(mM.values)

# %%
multi_dataDIR2M = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m03.1m_Ubottomdegrad.nc'
AZRM=xr.open_mfdataset(multi_dataDIR2M,concat_dim='t', combine='nested')
umean2M = AZRM.degraded_vozocrtx.mean(dim='t')

# %%
E2M=umean2M*umean2M
Ezoom2M=E2M[imin:imax,jmin:jmax]
m2M=Ezoom2M.mean(dim={'x','y'})
print(m2M.values)

# %%
#Ec mois de MARS
EcM=1/2*(m2M+mM)
print(EcM.values)

# %%
#moy mois de avril
multi_dataDIRZ = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m04.1m_Vbottomdegrad.nc'
AZZ=xr.open_mfdataset(multi_dataDIRZ,concat_dim='t', combine='nested')
umeanZ = AZZ.degraded_vomecrty.mean(dim='t')

# %%
EZ=umeanZ*umeanZ
EzoomZ=EZ[imin:imax,jmin:jmax]
mZ=EzoomZ.mean(dim={'x','y'})
print(mZ.values)

# %%
multi_dataDIR2Z = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m04.1m_Ubottomdegrad.nc'
AZRZ=xr.open_mfdataset(multi_dataDIR2Z,concat_dim='t', combine='nested')
umean2Z = AZRZ.degraded_vozocrtx.mean(dim='t')

# %%
E2Z=umean2Z*umean2Z
Ezoom2Z=E2Z[imin:imax,jmin:jmax]
m2Z=Ezoom2Z.mean(dim={'x','y'})
print(m2Z.values)

# %%
#Ec mois de avril
EcZ=1/2*(m2Z+mZ)
print(EcZ.values)

# %%
#moy mois de mai
multi_dataDIRm = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m05.1m_Vbottomdegrad.nc'
AZm=xr.open_mfdataset(multi_dataDIRm,concat_dim='t', combine='nested')
umeanm = AZm.degraded_vomecrty.mean(dim='t')

# %%
Em=umeanm*umeanm
Ezoomm=Em[imin:imax,jmin:jmax]
mm=Ezoomm.mean(dim={'x','y'})
print(mm.values)

# %%
multi_dataDIR2m = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m05.1m_Ubottomdegrad.nc'
AZRm=xr.open_mfdataset(multi_dataDIR2m,concat_dim='t', combine='nested')
umean2m = AZRm.degraded_vozocrtx.mean(dim='t')

# %%
E2m=umean2m*umean2m
Ezoom2m=E2m[imin:imax,jmin:jmax]
m2m=Ezoom2m.mean(dim={'x','y'})
print(m2m.values)

# %%
#Ec mois de mai
Ecm=1/2*(m2m+mm)
print(Ecm.values)

# %%
#moy mois de juin
multi_dataDIRj = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m06.1m_Vbottomdegrad.nc'
AZj=xr.open_mfdataset(multi_dataDIRj,concat_dim='t', combine='nested')
umeanj = AZj.degraded_vomecrty.mean(dim='t')

# %%
Ej=umeanj*umeanj
Ezoomj=Ej[imin:imax,jmin:jmax]
mj=Ezoomj.mean(dim={'x','y'})
print(mj.values)

# %%
multi_dataDIR2j = '/bettik/roussilh/noMED-degrad/mean/eNATL60noMED-BLBT02_y2010m06.1m_Ubottomdegrad.nc'
AZRj=xr.open_mfdataset(multi_dataDIR2j,concat_dim='t', combine='nested')
umean2j = AZRj.degraded_vozocrtx.mean(dim='t')

# %%
E2j=umean2j*umean2j
Ezoom2j=E2j[imin:imax,jmin:jmax]
m2j=Ezoom2j.mean(dim={'x','y'})
print(m2j.values)

# %%
#Ec mois de juin
Ecj=1/2*(m2j+mj)
print(Ecj.values)
