# %%
import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy.ma as ma
import numpy as np
import cmocean
import matplotlib
from numpy import zeros,array
# %matplotlib inline

# %%
L=array([0.0014411855,0.001192881,0.0009296175,0.001061071,0.0009737124,0.0009798233,0.0011350855,0.0010995787,0.0011871466,0.0012019672,0.0012140805,0.00139304])
print(L)
# Out:
# [0.00144119 0.00119288 0.00092962 0.00106107 0.00097371 0.00097982
#  0.00113509 0.00109958 0.00118715 0.00120197 0.00121408 0.00139304]

# %%
tableau = array([[0.0014411855, 0.001192881, 0.0009296175, 0.001061071, 0.0009737124, 0.0009798233, 0.0011350855, 0.0010995787, 0.0011871466, 0.0012019672, 0.0012140805, 0.00139304],['juillet','aout','septembre','octobre','novembre','decembre','janvier','fevrier','mars','avril','mai','juin']])
print(tableau)
# Out:
# [['0.0014411855' '0.001192881' '0.0009296175' '0.001061071'
#   '0.0009737124' '0.0009798233' '0.0011350855' '0.0010995787'
#   '0.0011871466' '0.0012019672' '0.0012140805' '0.00139304']
#  ['juillet' 'aout' 'septembre' 'octobre' 'novembre' 'decembre' 'janvier'
#   'fevrier' 'mars' 'avril' 'mai' 'juin']]

# %%
tableau.shape
# Out:
# 24

# %%
etype = np.std(L)
print(etype)
# Out:
# 0.00015087382723203037

# %%
plt.figure(figsize=(12,12))
plt.plot(L,c="red")
plt.title('Energie cinétique moyenne de juillet 2009 à juin 2010')
plt.xlabel('mois')
plt.ylabel('Ec moyenne')
errorL = [etype]
plt.errorbar(range(len(L)), L, yerr = errorL,
    fmt = 'none', capsize = 5, ecolor = 'red', elinewidth = 1, capthick = 2)
axes = plt.gca()
axes.xaxis.set_ticks(range(12)) 
axes.xaxis.set_ticklabels(['juillet', 'aout', 'septembre', 'octobre', 'novembre', 'decembre', 'janvier', 'fevrier', 'mars', 'avril', 'mai', 'juin'])
plt.savefig('Ec_moy_zone_gyre_subpolaire_jui09_juin10.png', bbbox_inches='tight')
# Out:
# /tmp/ipykernel_191285/1070926158.py:12: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbbox_inches" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('Ec_moy_zone_gyre_subpolaire_jui09_juin10.png', bbbox_inches='tight')
