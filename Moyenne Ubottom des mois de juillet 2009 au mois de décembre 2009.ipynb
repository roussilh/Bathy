# %%
import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import numpy.ma as ma
import numpy as np
import cmocean

# %matplotlib inline

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m07*U*.nc'
TAS1 = xr.open_mfdataset(multi_dataDIR)
TAS1
umean = TAS1.degraded_vozocrtx.mean(dim='time_counter')
vit0 = TAS1.degraded_vozocrtx.mean(dim='time_counter')
navlon = TAS1.nav_lon
navlat = TAS1.nav_lat
vit_mask0=ma.masked_where(vit0==0.,vit0)
lat0 = navlat.sel(time_counter='2009-07-01T00:30:00.000000000')
lon0 = navlon.sel(time_counter='2009-07-01T00:30:00.000000000')

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m08*U*.nc'
TAS2 = xr.open_mfdataset(multi_dataDIR)
TAS2
umean = TAS2.degraded_vozocrtx.mean(dim='time_counter')
vit1 = TAS2.degraded_vozocrtx.mean(dim='time_counter')
navlon = TAS2.nav_lon
navlat = TAS2.nav_lat
vit_mask=ma.masked_where(vit1==0.,vit1)
lat = navlat.sel(time_counter='2009-08-01T00:30:00.000000000')
lon = navlon.sel(time_counter='2009-08-01T00:30:00.000000000')

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m09*U*.nc'
TAS3 = xr.open_mfdataset(multi_dataDIR)
TAS3
umean = TAS3.degraded_vozocrtx.mean(dim='time_counter')
vit3 = TAS3.degraded_vozocrtx.mean(dim='time_counter')
navlon1 = TAS3.nav_lon
navlat1 = TAS3.nav_lat
vit_mask1=ma.masked_where(vit3==0.,vit3)
lat1 = navlat1.sel(time_counter='2009-09-01T00:30:00.000000000')
lon1 = navlon1.sel(time_counter='2009-09-01T00:30:00.000000000')

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m10*U*.nc'
TAS4 = xr.open_mfdataset(multi_dataDIR)
TAS4
umean = TAS4.degraded_vozocrtx.mean(dim='time_counter')
vit4 = TAS4.degraded_vozocrtx.mean(dim='time_counter')
navlon2 = TAS4.nav_lon
navlat2 = TAS4.nav_lat
vit_mask2=ma.masked_where(vit4==0.,vit4)
lat2 = navlat2.sel(time_counter='2009-10-01T00:30:00.000000000')
lon2 = navlon2.sel(time_counter='2009-10-01T00:30:00.000000000')

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m11*U*.nc'
TAS5 = xr.open_mfdataset(multi_dataDIR)
TAS5
umean = TAS5.degraded_vozocrtx.mean(dim='time_counter')
vit5 = TAS5.degraded_vozocrtx.mean(dim='time_counter')
navlon3 = TAS5.nav_lon
navlat3 = TAS5.nav_lat
vit_mask3=ma.masked_where(vit5==0.,vit5)
lat3 = navlat3.sel(time_counter='2009-11-01T00:30:00.000000000')
lon3 = navlon3.sel(time_counter='2009-11-01T00:30:00.000000000')

# %%
multi_dataDIR = '/bettik/roussilh/noMED-degrad/eNATL60noMED-BLBT02_y2009m12*U*.nc'
TAS6 = xr.open_mfdataset(multi_dataDIR)
TAS6
umean = TAS6.degraded_vozocrtx.mean(dim='time_counter')
vit6 = TAS6.degraded_vozocrtx.mean(dim='time_counter')
navlon4 = TAS6.nav_lon
navlat4 = TAS6.nav_lat
vit_mask4=ma.masked_where(vit6==0.,vit6)
lat4 = navlat4.sel(time_counter='2009-12-01T00:30:00.000000000')
lon4 = navlon4.sel(time_counter='2009-12-01T00:30:00.000000000')

# %%
fig1 = plt.figure(figsize=(12, 10), dpi=150)

ax0 = plt.subplot(131, projection=ccrs.PlateCarree())
f0 = ax0.pcolormesh(lon0, lat0, vit_mask0, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)
ax1 = plt.subplot(132, projection=ccrs.PlateCarree())
f1 = ax1.pcolormesh(lon, lat, vit_mask, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)

# %%
fig1 = plt.figure(figsize=(12, 10), dpi=150)

ax0 = plt.subplot(131, projection=ccrs.PlateCarree())
ax1 = plt.subplot(132, projection=ccrs.PlateCarree())
ax2 = plt.subplot(133, projection=ccrs.PlateCarree())
ax3 = plt.subplot(231, projection=ccrs.PlateCarree())
ax4 = plt.subplot(232, projection=ccrs.PlateCarree())
ax5 = plt.subplot(233, projection=ccrs.PlateCarree())

f0 = ax0.pcolormesh(lon0, lat0, vit_mask0, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)
    
f1 = ax1.pcolormesh(lon, lat, vit_mask, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)

f2 = ax2.pcolormesh(lon1, lat1, vit_mask1,
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)

f3 = ax3.pcolormesh(lon2, lat2, vit_mask2, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)

f4 = ax4.pcolormesh(lon3, lat3, vit_mask3, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)

f5 = ax5.pcolormesh(lon4, lat4, vit_mask4, 
                    shading='auto', transform = ccrs.PlateCarree(),
                    vmin=-1, vmax=1, cmap=cmocean.cm.balance)

grid_lines = ax0.gridlines(draw_labels = True)
grid_lines.xformatter = LONGITUDE_FORMATTER
grid_lines.yformatter = LATITUDE_FORMATTER
grid_lines.xlocator = mticker.FixedLocator(np.arange(-90,10,20))
grid_lines.ylocator = mticker.FixedLocator(np.arange(0,70,10))
grid_lines.ylabels_right = False
grid_lines.xlabels_top = False

grid_lines = ax1.gridlines(draw_labels = True)
grid_lines.xformatter = LONGITUDE_FORMATTER
grid_lines.yformatter = LATITUDE_FORMATTER
grid_lines.xlocator = mticker.FixedLocator(np.arange(-90,10,20))
grid_lines.ylocator = mticker.FixedLocator(np.arange(0,70,10))
grid_lines.ylabels_right = False
grid_lines.xlabels_top = False


grid_lines = ax2.gridlines(draw_labels = True)
grid_lines.xformatter = LONGITUDE_FORMATTER
grid_lines.yformatter = LATITUDE_FORMATTER
grid_lines.xlocator = mticker.FixedLocator(np.arange(-90,10,20))
grid_lines.ylocator = mticker.FixedLocator(np.arange(0,70,10))
grid_lines.ylabels_right = False
grid_lines.xlabels_top = False

grid_lines = ax3.gridlines(draw_labels = True)
grid_lines.xformatter = LONGITUDE_FORMATTER
grid_lines.yformatter = LATITUDE_FORMATTER
grid_lines.xlocator = mticker.FixedLocator(np.arange(-90,10,20))
grid_lines.ylocator = mticker.FixedLocator(np.arange(0,70,10))
grid_lines.ylabels_right = False
grid_lines.xlabels_top = False

grid_lines = ax4.gridlines(draw_labels = True)
grid_lines.xformatter = LONGITUDE_FORMATTER
grid_lines.yformatter = LATITUDE_FORMATTER
grid_lines.xlocator = mticker.FixedLocator(np.arange(-90,10,20))
grid_lines.ylocator = mticker.FixedLocator(np.arange(0,70,10))
grid_lines.ylabels_right = False
grid_lines.xlabels_top = False

grid_lines = ax5.gridlines(draw_labels = True)
grid_lines.xformatter = LONGITUDE_FORMATTER
grid_lines.yformatter = LATITUDE_FORMATTER
grid_lines.xlocator = mticker.FixedLocator(np.arange(-90,10,20))
grid_lines.ylocator = mticker.FixedLocator(np.arange(0,70,10))
grid_lines.ylabels_right = False
grid_lines.xlabels_top = False

cb1 = fig1.colorbar(f1, orientation="horizontal", fraction=0.05, pad=0.07)
cb1.set_label('mean Turbidity [FNU]', fontsize=18)
cb1.tick_params(labelsize=20)
 
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 10>()
#       7 ax4 = plt.subplot(232, projection=ccrs.PlateCarree())
#       8 ax5 = plt.subplot(233, projection=ccrs.PlateCarree())
# ---> 10 f0 = ax0.pcolormesh(lon0, lat0, vit_mask0,
#      11                     shading='auto', transform = ccrs.PlateCarree(),
#      12                     vmin=-1, vmax=1, cmap=cmocean.cm.balance)
#      14 f1 = ax1.pcolormesh(lon, lat, vit_mask,
#      15                     shading='auto', transform = ccrs.PlateCarree(),
#      16                     vmin=-1, vmax=1, cmap=cmocean.cm.balance)
#      18 f2 = ax2.pcolormesh(lon1, lat1, vit_mask1,
#      19                     shading='auto', transform = ccrs.PlateCarree(),
#      20                     vmin=-1, vmax=1, cmap=cmocean.cm.balance)
#
# ...
